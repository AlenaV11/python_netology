# %% [markdown]
# # **Задание 1**. Даны 2 строки: *long_phrase* и *short_phrase*.
# Напишите код, который проверяет действительно ли длинная фраза *long_phrase* длиннее короткой *short_phrase*. И выводит *True* или *False* в зависимости от результата сравнения.

# %%
len ('Насколько проще было бы писать программы, если бы не заказчики') > \
len ('640Кб должно хватить для любых задач. Билл Гейтс (по легенде)')

# %%
# или
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
long_phrase > short_phrase

# %%
# или
long_phrase = 'Насколько проще было бы писать программы, если бы не заказчики'
short_phrase = '640Кб должно хватить для любых задач. Билл Гейтс (по легенде)'
len (long_phrase) > len (short_phrase)

# %% [markdown]
# # Задание 2. Дано значение объема файла в байтах.
# Напишите перевод этого значения в мегабайты в формате: "Объем файла равен 213.68Mb"

# %%
# 1 вариант

x = 224059719.68
v = x / (1024 ** 2)
print ("Объем файла равен", v, "Mb")

# %%
# 2 вариант

x = float(input("Введите объем файла "))
v = x / (1024 ** 2)
print ("Объем файла равен", v, "Mb")

# %% [markdown]
# # **Задание 3**. Разработать приложение для определения знака зодиака по дате рождения. Пример:
#
# Введите месяц: март
#
# Введите число: 6
#
# Вывод:
# Рыбы

# %%
zodiac_month = int(input("Введите месяц "))
zodiac_date = int(input("Введите число "))


# РЫЫ МАРТ
if zodiac_month == 3:
    if zodiac_date >= 21 and zodiac_date <= 31:
        print("Ваш зодиак: Овен")
else:
    pass

# РЫБЫ АПРЕЛЬ
if zodiac_month == 4:
    if zodiac_date >= 1 and zodiac_date <= 19:
        print("Ваш зодиак: Овен")
else:
    pass



# ТЕЛЕЦ АПРЕЛЬ
if zodiac_month == 4:
    if zodiac_date >= 20 and zodiac_date <= 30:
        print("Ваш зодиак: Телец")
else:
    pass
# ТЕЛЕЦ МАЙ
if zodiac_month == 5:
    if zodiac_date >= 1 and zodiac_date <= 20:
        print("Ваш зодиак: Телец")
else:
    pass



# БЛИЗНЕЦЫ МАЙ
if zodiac_month == 5:
    if zodiac_date >= 21 and zodiac_date <= 31:
        print("Ваш зодиак: Близнецы")
else:
    pass
# БЛИЗНЕЦЫ ИЮНЬ
if zodiac_month == 6:
    if zodiac_date >= 1 and zodiac_date <= 20:
        print("Ваш зодиак: Близнецы")
else:
    pass



# РАК ИЮНЬ
if zodiac_month == 6:
    if zodiac_date >= 21 and zodiac_date <= 30:
        print("Ваш зодиак: Рак")
else:
    pass
# РАК ИЮЛЬ
if zodiac_month == 7:
    if zodiac_date >= 1 and zodiac_date <= 22:
        print("Ваш зодиак: Рак")
else:
    pass



# ЛЕВ ИЮЛЬ
if zodiac_month == 7:
    if zodiac_date >= 23 and zodiac_date <= 31:
        print("Ваш зодиак: Лев")
else:
    pass
# ЛЕВ АВГУСТ
if zodiac_month == 8:
    if zodiac_date >= 1 and zodiac_date <= 22:
        print("Ваш зодиак: Лев")
else:
    pass



# ДЕВА АВГУСТ
if zodiac_month == 8:
    if zodiac_date >= 23 and zodiac_date <= 31:
        print("Ваш зодиак: Дева")
else:
    pass
# ДЕВА СЕНТЯБРЬ
if zodiac_month == 9:
    if zodiac_date >= 1 and zodiac_date <= 22:
        print("Ваш зодиак: Дева")
else:
    pass



# ВЕСЫ СЕНТЯБРЬ
if zodiac_month == 9:
    if zodiac_date >= 23 and zodiac_date <= 30:
        print("Ваш зодиак: Весы")
else:
    pass
# ВЕСЫ ОКТЯБРЬ
if zodiac_month == 10:
    if zodiac_date >= 1 and zodiac_date <= 22:
        print("Ваш зодиак: Весы")
else:
    pass



# СКОРПИОН ОКТЯБРЬ
if zodiac_month == 10:
    if zodiac_date >= 23 and zodiac_date <= 31:
        print("Ваш зодиак: Скорпион")
else:
    pass
# СКОРПИОН НОЯБРЬ
if zodiac_month == 11:
    if zodiac_date >= 1 and zodiac_date <= 21:
        print("Ваш зодиак: Скорпион")
else:
    pass



# СТРЕЛЕЦ НОЯБРЬ
if zodiac_month == 11:
    if zodiac_date >= 22 and zodiac_date <= 30:
        print("Ваш зодиак: Стрелец")
else:
    pass

# СТРЕЛЕЦ ДЕКАБРЬ
if zodiac_month == 12:
    if zodiac_date >= 1 and zodiac_date <= 21:
        print("Ваш зодиак: Стрелец")
else:
    pass



# КОЗЕРОГ ДЕКАБРЬ
if zodiac_month == 12:
    if zodiac_date >= 22 and zodiac_date <= 31:
        print("Ваш зодиак: Козерог")
else:
    pass

# КОЗЕРОГ ЯНВАРЬ
if zodiac_month == 1:
    if zodiac_date >= 1 and zodiac_date <= 19:
        print("Ваш зодиак: Козерог")
else:
    pass



# ВОДОЛЕЦ ЯНВАРЬ
if zodiac_month == 1:
    if zodiac_date >= 20 and zodiac_date <= 31:
        print("Ваш зодиак: Водолец")
else:
    pass

# ВОДОЛЕЦ ФЕВРАЛЬ
if zodiac_month == 2:
    if zodiac_date >= 1 and zodiac_date <= 18:
        print("Ваш зодиак: Водолец")
else:
    pass



# РЫБЫ ФЕВРАЛЬ
if zodiac_month == 2:
    if zodiac_date >= 19 and zodiac_date <= 28:
        print("Ваш зодиак: Рыбы")
else:
    pass

# РЫБЫ МАРТ
if zodiac_month == 3:
    if zodiac_date >= 1 and zodiac_date <= 20:
        print("Ваш зодиак: Рыбы")
else:
    pass

# %% [markdown]
# # **Задание 4**. Нужно разработать приложение для финансового планирования.
# Приложение учитывает сколько уходит на ипотеку, "на жизнь" и сколько нужно отложить на пенсию.
# Пользователь вводит:
# - заработанную плату в месяц.
# - сколько процентов от ЗП уходит на ипотеку.
# - сколько процентов от ЗП уходит "на жизнь".
# - сколько раз приходит премия в год.
#
# Остальная часть заработанной платы откладывается на пенсию.
#
# Также пользователю приходит премия в размере зарплаты, от которой половина уходит на отпуск, а вторая половина откладывается.
#
# Программа должна учитывать сколько премий было в год.
#
# Нужно вывести сколько денег тратит пользователь на ипотеку и сколько он накопит за год.
#
# Пример:
#
# Введите заработанную плату в месяц: 100000
#
# Введите сколько процентов уходит на ипотеку: 30
#
# Введите сколько процентов уходит на жизнь: 50
#
# Введите количество премий за год: 2
#
# Вывод:
# На ипотеку было потрачено: 360000 рублей
# Было накоплено: 340000 рублей

# %%
wage = float (input("Введите заработную плату в месяц ")) # з/п в месяц, руб
m = float (input ("Введите сколько % уходит на ипотеку ")) # ипотека, %
l = float (input ("Введите сколько % уходит на жизнь ")) # на жизнь, %
p = float (input ("Введите количество премий за год ")) # кол-во премий, шт

life = wage * l / 100 # на жизнь, мес, руб
mortgage = wage * m / 100 # ипотека, мес, руб
benefit = wage - life - mortgage # пенсия, мес, руб
prize = p * wage # премия, руб
vacation = 0.5 * prize # на отпуск, руб
account = 0.5 * prize # накоплено, руб
accrued = account + (benefit*12) # накоплено, руб за год

print ("Вывод: на ипотеку было потрачено: ", mortgage * 12, " рублей. Было накоплено: ", accrued, " рублей.")
